# %%
import pandas as pd

# %%
data = pd.read_json('Indian_Number_plates.json',lines= True)

# %%
data
# Out:
#                                                content  \
# 0    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 1    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 2    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 3    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 4    http://com.dataturks.a96-i23.open.s3.amazonaws...
# ..                                                 ...
# 232  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 233  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 234  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 235  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 236  http://com.dataturks.a96-i23.open.s3.amazonaws...
#
#                                             annotation  extras
# 0    [{'label': ['number_plate'], 'notes': '', 'poi...     NaN
# 1    [{'label': ['number_plate'], 'notes': '', 'poi...     NaN
# 2    [{'label': ['number_plate'], 'notes': '', 'poi...     NaN
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                              content  \
# 0  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 1  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 2  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 3  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 4  http://com.dataturks.a96-i23.open.s3.amazonaws...
#
#                                           annotation  extras
# 0  [{'label': ['number_plate'], 'notes': '', 'poi...     NaN
# 1  [{'label': ['number_plate'], 'notes': '', 'poi...     NaN
# 2  [{'label': ['number_plate'], 'notes': '', 'poi...     NaN
# 3  [{'label': ['number_plate'], 'notes': '', 'poi...     NaN
# 4  [{'label': ['number_plate'], 'notes': '', 'poi...     NaN

# %%
df.drop('extras',axis=1,inplace=True)

# %%
df['content']
# Out:
# 0      http://com.dataturks.a96-i23.open.s3.amazonaws...
# 1      http://com.dataturks.a96-i23.open.s3.amazonaws...
# 2      http://com.dataturks.a96-i23.open.s3.amazonaws...
# 3      http://com.dataturks.a96-i23.open.s3.amazonaws...
# 4      http://com.dataturks.a96-i23.open.s3.amazonaws...
#                              ...
# 232    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 233    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 234    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 235    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 236    http://com.dataturks.a96-i23.open.s3.amazonaws...
# Name: content, Length: 237, dtype: object

# %%
print(data['annotation'][1][0]['imageHeight'])
print(data['annotation'][1][0]['imageWidth'])
# Out:
# 449
# 494

# %%
x_min = []
x_max = []
y_min = []
y_max = []
h = []
w = []

for i in range(237):
    x_min.append(data['annotation'][i][0]['points'][0]['x'])
    x_max.append(data['annotation'][i][0]['points'][1]['x'])
    y_min.append(data['annotation'][i][0]['points'][0]['y'])
    y_max.append(data['annotation'][i][0]['points'][1]['y'])
    h.append(data['annotation'][i][0]['imageHeight'])
    w.append(data['annotation'][i][0]['imageWidth'])

# %%
type(x_min)
# Out:
# list

# %%
df['x_min'] = x_min
df['y_min'] = y_min
df['x_max'] = x_max
df['y_max'] = y_max

# %%
df['width'] = w
df['height'] = h

# %%
df['class'] = ['license']*237

# %%
df['filename'] = [str(i)+'jpg' for i in range(237)]

# %%
df.head()
# Out:
#                                              content  \
# 0  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 1  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 2  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 3  http://com.dataturks.a96-i23.open.s3.amazonaws...
# 4  http://com.dataturks.a96-i23.open.s3.amazonaws...
#
#                                           annotation filename  width  height  \
# 0  [{'label': ['number_plate'], 'notes': '', 'poi...     0jpg    806     466
# 1  [{'label': ['number_plate'], 'notes': '', 'poi...     1jpg    494     449
# 2  [{'label': ['number_plate'], 'notes': '', 'poi...     2jpg    500     314
# 3  [{'label': ['number_plate'], 'notes': '', 'poi...     3jpg    500     469
# 4  [{'label': ['number_plate'], 'notes': '', 'poi...     4jpg   1001     563
#
#      class     x_min     y_min     x_max     y_max
# 0  license  0.722084  0.587983  0.868486  0.688841
# 1  license  0.161943  0.850780  0.582996  1.000000
# ...

# %%
df.drop(['content','annotation'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   filename  width  height    class     x_min     y_min     x_max     y_max
# 0     0jpg    806     466  license  0.722084  0.587983  0.868486  0.688841
# 1     1jpg    494     449  license  0.161943  0.850780  0.582996  1.000000
# 2     2jpg    500     314  license  0.082000  0.697452  0.230000  0.828025
# 3     3jpg    500     469  license  0.434000  0.667377  0.718000  0.765458
# 4     4jpg   1001     563  license  0.208791  0.390764  0.865135  0.984014

# %%
df.to_csv(index=False)
# Out:
# 'filename,x_min,x_max,y_min,y_max,height,width,class\r\n0jpg,0.722084367245657,0.8684863523573201,0.5879828326180251,0.688841201716738,466,806,license\r\n1jpg,0.16194331983805602,0.582995951417004,0.850779510022271,1.0,449,494,license\r\n2jpg,0.082,0.23,0.697452229299363,0.8280254777070061,314,500,license\r\n3jpg,0.434,0.718,0.667377398720682,0.7654584221748401,469,500,license\r\n4jpg,0.20879120879120802,0.865134865134865,0.39076376554174,0.9840142095914741,563,1001,license\r\n5jpg,0.254807692307692,0.627403846153846,0.649651972157772,0.7772621809744781,431,416,license\r\n6jpg,0.411978221415607,0.8058076225045371,0.529670329670329,0.6923076923076921,455,551,license\r\n7jpg,0.48545454545454503,0.72,0.461824953445065,0.595903165735568,537,550,license\r\n8jpg,0.410757946210268,0.5688671556642211,0.453714285714285,0.516571428571428,1119,1569,license\r\n9jpg,0.41320293398533003,0.58679706601467,0.397101449275362,0.623188405797101,918,1632,license\r\n10jpg,0.311526479750778,0.6573208722741
# ...

# %%
df1 = df[:201]

# %%
df2 = df[201:]

# %%
len(df1)
# Out:
# 201

# %%
len(df2)
# Out:
# 36

# %%
df1.head()
# Out:
#   filename  width  height    class     x_min     y_min     x_max     y_max
# 0     0jpg    806     466  license  0.722084  0.587983  0.868486  0.688841
# 1     1jpg    494     449  license  0.161943  0.850780  0.582996  1.000000
# 2     2jpg    500     314  license  0.082000  0.697452  0.230000  0.828025
# 3     3jpg    500     469  license  0.434000  0.667377  0.718000  0.765458
# 4     4jpg   1001     563  license  0.208791  0.390764  0.865135  0.984014

# %%
df2.head()
# Out:
#     filename  width  height    class     x_min     y_min     x_max     y_max
# 201   201jpg    630     353  license  0.398413  0.529745  0.595238  0.662890
# 202   202jpg    500     333  license  0.198000  0.615616  0.818000  0.933934
# 203   203jpg    600     430  license  0.406667  0.534884  0.628333  0.706977
# 204   204jpg    442     333  license  0.361991  0.633634  0.644796  0.789790
# 205   205jpg    602     339  license  0.166113  0.460177  0.445183  0.640118

# %%
train_labels = df1.to_csv (r'train_labels.csv', index = None, header=True)
test_labels = df2.to_csv (r'test_labels.csv', index = None, header=True)
